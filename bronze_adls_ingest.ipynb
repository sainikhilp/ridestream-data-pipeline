# %%
import pandas as pd

files = [
{"file" : "map_cities"},
{"file" : "map_cancellation_reasons"},
{"file" : "bulk_rides"},
{"file" : "map_payment_methods"},
{"file" : "map_ride_statuses"},
{"file" : "map_vehicle_makes"},
{"file" : "map_vehicle_types"}
]

for item in files:


    url = f"https://adlstaxiproject.blob.core.windows.net/raw/ingestion/{item['file']}.json?sp=r&st=2026-03-22T04:25:01Z&se=2026-03-24T00:40:01Z&spr=https&sv=2024-11-04&sr=c&sig=bU4rTa%2Bv3In8MLEN7bsp9CTF71zlyjKBMQKtzkk8YTg%3D"

    df = pd.read_json(url)

    df_spark = spark.createDataFrame(df)

    df_spark.write.format("delta")\
                  .mode("overwrite")\
                  .saveAsTable(f"ridestream.bronze.{item['file']}")

# %%
# %sql
SELECT * FROM ridestream.bronze.bulk_rides
